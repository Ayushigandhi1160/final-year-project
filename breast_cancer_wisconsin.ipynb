# %%
# Install required packages
# !pip install imbalanced-learn shap
# Out:
# Requirement already satisfied: imbalanced-learn in /usr/local/lib/python3.11/dist-packages (0.13.0)
# Requirement already satisfied: shap in /usr/local/lib/python3.11/dist-packages (0.48.0)
# Requirement already satisfied: numpy<3,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (2.0.2)
# Requirement already satisfied: scipy<2,>=1.10.1 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (1.15.3)
# Requirement already satisfied: scikit-learn<2,>=1.3.2 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (1.6.1)
# Requirement already satisfied: sklearn-compat<1,>=0.1 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (0.1.3)
# Requirement already satisfied: joblib<2,>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl<4,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from imbalanced-learn) (3.6.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from shap) (2.2.2)
# Requirement already satisfied: tqdm>=4.27.0 in /usr/local/lib/python3.11/dist-packages (from shap) (4.67.1)
# Requirement already satisfied: packaging>20.9 in /usr/local/lib/python3.11/dist-packages (from shap) (24.2)
# Requirement already satisfied: slicer==0.0.8 in /usr/local/lib/python3.11/dist-packages (from shap) (0.0.8)
# Requirement already satisfied: numba>=0.54 in /usr/local/lib/python3.11/dist-packages (from shap) (0.60.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from shap) (3.1.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from shap) (4.14.0)
# Requirement already satisfied: llvmlite<0.44,>=0.43.0dev0 in /usr/local/lib/python3.11/dist-packages (from numba>=0.54->shap) (0.43.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->shap) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->shap) (1.17.0)

# %% [markdown]
# # **Load Librarires**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score, roc_curve, ConfusionMatrixDisplay
from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import GradientBoostingClassifier
from imblearn.over_sampling import SMOTE
import shap

# %% [markdown]
# # **Load dataset**

# %%
# Load dataset
url = "https://archive.ics.uci.edu/ml/machine-learning-databases/breast-cancer-wisconsin/wdbc.data"
columns = ['ID', 'Diagnosis'] + [f'feature_{i}' for i in range(1, 31)]
data = pd.read_csv(url, header=None, names=columns)

# %%
data.head()
# Out:
#          ID Diagnosis  feature_1  feature_2  feature_3  feature_4  feature_5  \
# 0    842302         M      17.99      10.38     122.80     1001.0    0.11840
# 1    842517         M      20.57      17.77     132.90     1326.0    0.08474
# 2  84300903         M      19.69      21.25     130.00     1203.0    0.10960
# 3  84348301         M      11.42      20.38      77.58      386.1    0.14250
# 4  84358402         M      20.29      14.34     135.10     1297.0    0.10030
#
#    feature_6  feature_7  feature_8  ...  feature_21  feature_22  feature_23  \
# 0    0.27760     0.3001    0.14710  ...       25.38       17.33      184.60
# 1    0.07864     0.0869    0.07017  ...       24.99       23.41      158.80
# 2    0.15990     0.1974    0.12790  ...       23.57       25.53      152.50
# 3    0.28390     0.2414    0.10520  ...       14.91       26.50       98.87
# 4    0.13280     0.1980    0.10430  ...       22.54       16.67      152.20
#
#    feature_24  feature_25  feature_26  feature_27  feature_28  feature_29  \
# 0      2019.0      0.1622      0.6656      0.7119      0.2654      0.4601
# 1      1956.0      0.1238      0.1866      0.2416      0.1860      0.2750
# 2      1709.0      0.1444      0.4245      0.4504      0.2430      0.3613
# 3       567.7      0.2098      0.8663      0.6869      0.2575      0.6638
# 4      1575.0      0.1374      0.2050      0.4000      0.1625      0.2364
#
#    feature_30
# 0     0.11890
# 1     0.08902
# 2     0.08758
# 3     0.17300
# 4     0.07678
#
# [5 rows x 32 columns]

# %%
data.columns
# Out:
# Index(['ID', 'Diagnosis', 'feature_1', 'feature_2', 'feature_3', 'feature_4',
#        'feature_5', 'feature_6', 'feature_7', 'feature_8', 'feature_9',
#        'feature_10', 'feature_11', 'feature_12', 'feature_13', 'feature_14',
#        'feature_15', 'feature_16', 'feature_17', 'feature_18', 'feature_19',
#        'feature_20', 'feature_21', 'feature_22', 'feature_23', 'feature_24',
#        'feature_25', 'feature_26', 'feature_27', 'feature_28', 'feature_29',
#        'feature_30'],
#       dtype='object')

# %% [markdown]
# # **Preprocessing**

# %% [markdown]
# ## **Drop ID colom**

# %%
data.drop('ID', axis=1, inplace=True)

# %% [markdown]
# ## **Label Encodding**

# %%
data['Diagnosis'] = data['Diagnosis'].map({'M': 1, 'B': 0})

# %% [markdown]
# # **Exploratry Data Analysis**

# %% [markdown]
# ## **Class Distribution**

# %%
sns.countplot(x='Diagnosis', data=data)
plt.title("Diagnosis Class Distribution (0=Benign, 1=Malignant)")
plt.show()

# %% [markdown]
# ## **Correlation HeatMAP**

# %%
plt.figure(figsize=(12, 10))
sns.heatmap(data.corr(), cmap='coolwarm', annot=False)
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# ## **Histogram**

# %%
# histogram

data.drop('Diagnosis', axis=1).hist(figsize=(15, 10), bins=20)
plt.suptitle("Distribution of All Features", fontsize=16)
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Standard Scale the Features**

# %%
# Preprocessing
X = data.drop('Diagnosis', axis=1)
y = data['Diagnosis']
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %% [markdown]
# #**Data Splitting**

# %%
# Split 80 percent use fro training and 20 percent for test
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (455, 30)

# %%
X_test.shape
# Out:
# (114, 30)

# %%
# Models
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000),
    "k-NN": KNeighborsClassifier(),
    "Gradient Boosting": GradientBoostingClassifier(random_state=42)
}

# Evaluate
for name, model in models.items():
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    print(f"\n{name} Report:\n", classification_report(y_test, y_pred))
    disp = ConfusionMatrixDisplay.from_estimator(model, X_test, y_test)
    disp.ax_.set_title(f'{name} Confusion Matrix')
    plt.show()
# Out:
# Logistic Regression Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        71
#            1       0.98      0.95      0.96        43
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
# k-NN Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        71
#            1       0.93      0.93      0.93        43
#
#     accuracy                           0.95       114
#    macro avg       0.94      0.94      0.94       114
# weighted avg       0.95      0.95      0.95       114
# Gradient Boosting Report:
#                precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97        71
#            1       0.95      0.93      0.94        43
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.95      0.95       114
# weighted avg       0.96      0.96      0.96       114

# %%
# ROC Curves
plt.figure(figsize=(8, 6))
for name, model in models.items():
    y_prob = model.predict_proba(X_test)[:, 1]
    fpr, tpr, _ = roc_curve(y_test, y_prob)
    auc = roc_auc_score(y_test, y_prob)
    plt.plot(fpr, tpr, label=f"{name} (AUC = {auc:.2f})")

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Comparison")
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Apply SMOTE**

# %%
import matplotlib.pyplot as plt
# Apply SMOTE on the training data
smote = SMOTE(random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train, y_train)

print("Shape of training data after SMOTE:", X_train_smote.shape)
print("Class distribution of training data after SMOTE:\n", y_train_smote.value_counts())

# Train and evaluate models on SMOTE data
print("\n--- Evaluation with SMOTE applied ---")
for name, model in models.items():
    print(f"\nTraining {name} with SMOTE data...")
    model.fit(X_train_smote, y_train_smote)
    y_pred_smote = model.predict(X_test)
    print(f"\n{name} Report (SMOTE):\n", classification_report(y_test, y_pred_smote))
    disp = ConfusionMatrixDisplay.from_estimator(model, X_test, y_test)
    disp.ax_.set_title(f'{name} Confusion Matrix (SMOTE)')
    plt.show()

# ROC Curves for SMOTE models
plt.figure(figsize=(8, 6))
for name, model in models.items():
    y_prob_smote = model.predict_proba(X_test)[:, 1]
    fpr_smote, tpr_smote, _ = roc_curve(y_test, y_prob_smote)
    auc_smote = roc_auc_score(y_test, y_prob_smote)
    plt.plot(fpr_smote, tpr_smote, label=f"{name} (SMOTE AUC = {auc_smote:.2f})")

plt.plot([0, 1], [0, 1], 'k--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve Comparison (SMOTE)")
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Shape of training data after SMOTE: (572, 30)
# Class distribution of training data after SMOTE:
#  Diagnosis
# 0    286
# 1    286
# Name: count, dtype: int64
#
# --- Evaluation with SMOTE applied ---
#
# Training Logistic Regression with SMOTE data...
#
# Logistic Regression Report (SMOTE):
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        71
#            1       0.98      0.98      0.98        43
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114
# Training k-NN with SMOTE data...
#
# k-NN Report (SMOTE):
#                precision    recall  f1-score   support
#
#            0       0.97      0.96      0.96        71
#            1       0.93      0.95      0.94        43
#
#     accuracy                           0.96       114
#    macro avg       0.95      0.96      0.95       114
# weighted avg       0.96      0.96      0.96       114
# Training Gradient Boosting with SMOTE data...
#
# Gradient Boosting Report (SMOTE):
#                precision    recall  f1-score   support
#
#            0       0.97      0.97      0.97        71
#            1       0.95      0.95      0.95        43
#
#     accuracy                           0.96       114
#    macro avg       0.96      0.96      0.96       114
# weighted avg       0.96      0.96      0.96       114

# %% [markdown]
# # **Visualize the SHAP values**

# %%
# Train the Logistic Regression model for SHAP analysis
lr_model_smote = LogisticRegression(max_iter=1000)
lr_model_smote.fit(X_train_smote, y_train_smote)

# Create a SHAP explainer for the Logistic Regression model
# Using a background dataset (e.g., training data) to approximate the expectation
explainer = shap.Explainer(lr_model_smote, X_train_smote)

# Calculate SHAP values for the test set
shap_values = explainer(X_test)

# Visualize the SHAP values
# Summary plot of SHAP values
shap.summary_plot(shap_values, features=X_test, feature_names=X.columns)

# Beeswarm plot of SHAP values (shows distribution and magnitude)
shap.summary_plot(shap_values, features=X_test, feature_names=X.columns, plot_type="layered_violin")

# # Optional: Individual explanation for a specific test sample
# sample_idx = 0 # Choose an index from the test set
# shap.plots.waterfall(shap_values[sample_idx], feature_names=X.columns)

# %% [markdown]
# # **DEEP Learning Model**

# %%
import matplotlib.pyplot as plt
# !pip install tensorflow

import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, GRU, Dense, Dropout
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping

# Reshape data for RNNs (samples, timesteps, features)
# For this dataset, we treat each sample as a single timestep
X_train_reshaped = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test_reshaped = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))

# Reshape SMOTE data
X_train_smote_reshaped = X_train_smote.reshape((X_train_smote.shape[0], 1, X_train_smote.shape[1]))

# Define LSTM Model
lstm_model = Sequential()
lstm_model.add(LSTM(64, input_shape=(X_train_reshaped.shape[1], X_train_reshaped.shape[2])))
lstm_model.add(Dropout(0.2))
lstm_model.add(Dense(1, activation='sigmoid'))

lstm_model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# Define GRU Model
gru_model = Sequential()
gru_model.add(GRU(64, input_shape=(X_train_reshaped.shape[1], X_train_reshaped.shape[2])))
gru_model.add(Dropout(0.2))
gru_model.add(Dense(1, activation='sigmoid'))

gru_model.compile(loss='binary_crossentropy', optimizer=Adam(learning_rate=0.001), metrics=['accuracy'])

# Early Stopping to prevent overfitting
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)

# Train LSTM Model (on SMOTE data)
print("\n--- Training LSTM Model (with SMOTE) ---")
lstm_history = lstm_model.fit(X_train_smote_reshaped, y_train_smote, epochs=100, batch_size=32,
                              validation_split=0.2, callbacks=[early_stopping], verbose=1)

# Train GRU Model (on SMOTE data)
print("\n--- Training GRU Model (with SMOTE) ---")
gru_history = gru_model.fit(X_train_smote_reshaped, y_train_smote, epochs=100, batch_size=32,
                            validation_split=0.2, callbacks=[early_stopping], verbose=1)

# Evaluate LSTM Model
print("\n--- Evaluating LSTM Model ---")
lstm_loss, lstm_acc = lstm_model.evaluate(X_test_reshaped, y_test, verbose=0)
print(f"LSTM Test Accuracy: {lstm_acc:.4f}")

y_pred_lstm = (lstm_model.predict(X_test_reshaped) > 0.5).astype("int32")
print("LSTM Classification Report:\n", classification_report(y_test, y_pred_lstm))
disp = ConfusionMatrixDisplay.from_predictions(y_test, y_pred_lstm)
disp.ax_.set_title('LSTM Confusion Matrix')
plt.show()

# Evaluate GRU Model
print("\n--- Evaluating GRU Model ---")
gru_loss, gru_acc = gru_model.evaluate(X_test_reshaped, y_test, verbose=0)
print(f"GRU Test Accuracy: {gru_acc:.4f}")

y_pred_gru = (gru_model.predict(X_test_reshaped) > 0.5).astype("int32")
print("GRU Classification Report:\n", classification_report(y_test, y_pred_gru))
disp = ConfusionMatrixDisplay.from_predictions(y_test, y_pred_gru)
disp.ax_.set_title('GRU Confusion Matrix')
plt.show()

# Plot History Graphs
def plot_history(history, model_name):
  plt.figure(figsize=(12, 5))

  # Plot training & validation accuracy values
  plt.subplot(1, 2, 1)
  plt.plot(history.history['accuracy'])
  plt.plot(history.history['val_accuracy'])
  plt.title(f'{model_name} Model Accuracy')
  plt.ylabel('Accuracy')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Validation'], loc='upper left')

  # Plot training & validation loss values
  plt.subplot(1, 2, 2)
  plt.plot(history.history['loss'])
  plt.plot(history.history['val_loss'])
  plt.title(f'{model_name} Model Loss')
  plt.ylabel('Loss')
  plt.xlabel('Epoch')
  plt.legend(['Train', 'Validation'], loc='upper left')

  plt.tight_layout()
  plt.show()

plot_history(lstm_history, 'LSTM')
plot_history(gru_history, 'GRU')
# Out:
# Requirement already satisfied: tensorflow in /usr/local/lib/python3.11/dist-packages (2.18.0)
# Requirement already satisfied: absl-py>=1.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.4.0)
# Requirement already satisfied: astunparse>=1.6.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from tensorflow) (24.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (5.29.5)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from tensorflow) (75.2.0)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.1.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (4.14.0)
# Requirement already satisfied: wrapt>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (1.73.0)
# Requirement already satisfied: tensorboard<2.19,>=2.18 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.18.0)
# Requirement already satisfied: keras>=3.5.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.8.0)
# Requirement already satisfied: numpy<2.1.0,>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (2.0.2)
# Requirement already satisfied: h5py>=3.11.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (3.14.0)
# Requirement already satisfied: ml-dtypes<0.5.0,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.4.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /usr/local/lib/python3.11/dist-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /usr/local/lib/python3.11/dist-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (13.9.4)
# Requirement already satisfied: namex in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.1.0)
# Requirement already satisfied: optree in /usr/local/lib/python3.11/dist-packages (from keras>=3.5.0->tensorflow) (0.16.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.21.0->tensorflow) (2025.6.15)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.8.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard<2.19,>=2.18->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard<2.19,>=2.18->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->keras>=3.5.0->tensorflow) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
#
# --- Training LSTM Model (with SMOTE) ---
# Epoch 1/100
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.8192 - loss: 0.6211 - val_accuracy: 0.8870 - val_loss: 0.4592
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9004 - loss: 0.4682 - val_accuracy: 0.9130 - val_loss: 0.3512
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9274 - loss: 0.3741 - val_accuracy: 0.9130 - val_loss: 0.2917
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9432 - loss: 0.3034 - val_accuracy: 0.9217 - val_loss: 0.2466
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9364 - loss: 0.2643 - val_accuracy: 0.9652 - val_loss: 0.2069
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9542 - loss: 0.2032 - val_accuracy: 0.9652 - val_loss: 0.1800
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9625 - loss: 0.1812 - val_accuracy: 0.9652 - val_loss: 0.1561
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9562 - loss: 0.1527 - val_accuracy: 0.9739 - val_loss: 0.1347
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9636 - loss: 0.1484 - val_accuracy: 0.9826 - val_loss: 0.1169
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9853 - loss: 0.1148 - val_accuracy: 0.9826 - val_loss: 0.1037
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9849 - loss: 0.1071 - val_accuracy: 0.9913 - val_loss: 0.0916
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9826 - loss: 0.1189 - val_accuracy: 0.9913 - val_loss: 0.0791
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9826 - loss: 0.0890 - val_accuracy: 0.9913 - val_loss: 0.0721
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9750 - loss: 0.1034 - val_accuracy: 0.9913 - val_loss: 0.0645
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9828 - loss: 0.0918 - val_accuracy: 0.9913 - val_loss: 0.0589
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9816 - loss: 0.0945 - val_accuracy: 0.9913 - val_loss: 0.0538
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9840 - loss: 0.0827 - val_accuracy: 0.9913 - val_loss: 0.0495
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9941 - loss: 0.0552 - val_accuracy: 0.9913 - val_loss: 0.0459
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9802 - loss: 0.0758 - val_accuracy: 0.9913 - val_loss: 0.0427
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9890 - loss: 0.0629 - val_accuracy: 0.9913 - val_loss: 0.0404
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9826 - loss: 0.0732 - val_accuracy: 0.9913 - val_loss: 0.0380
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9811 - loss: 0.0703 - val_accuracy: 0.9913 - val_loss: 0.0359
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9929 - loss: 0.0540 - val_accuracy: 0.9913 - val_loss: 0.0344
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9894 - loss: 0.0520 - val_accuracy: 0.9913 - val_loss: 0.0330
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9858 - loss: 0.0606 - val_accuracy: 0.9913 - val_loss: 0.0317
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9734 - loss: 0.0744 - val_accuracy: 0.9913 - val_loss: 0.0310
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9903 - loss: 0.0502 - val_accuracy: 0.9913 - val_loss: 0.0292
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9821 - loss: 0.0582 - val_accuracy: 0.9913 - val_loss: 0.0270
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9826 - loss: 0.0578 - val_accuracy: 0.9913 - val_loss: 0.0250
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9840 - loss: 0.0460 - val_accuracy: 0.9913 - val_loss: 0.0241
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9897 - loss: 0.0464 - val_accuracy: 0.9913 - val_loss: 0.0230
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9815 - loss: 0.0684 - val_accuracy: 0.9913 - val_loss: 0.0220
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9832 - loss: 0.0521 - val_accuracy: 0.9913 - val_loss: 0.0221
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9895 - loss: 0.0461 - val_accuracy: 0.9913 - val_loss: 0.0217
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9887 - loss: 0.0485 - val_accuracy: 0.9913 - val_loss: 0.0192
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9894 - loss: 0.0413 - val_accuracy: 0.9913 - val_loss: 0.0185
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9837 - loss: 0.0458 - val_accuracy: 0.9913 - val_loss: 0.0187
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9842 - loss: 0.0439 - val_accuracy: 0.9913 - val_loss: 0.0181
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9850 - loss: 0.0472 - val_accuracy: 0.9913 - val_loss: 0.0175
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9911 - loss: 0.0406 - val_accuracy: 0.9913 - val_loss: 0.0172
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9881 - loss: 0.0351 - val_accuracy: 0.9913 - val_loss: 0.0154
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9956 - loss: 0.0313 - val_accuracy: 1.0000 - val_loss: 0.0145
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9881 - loss: 0.0366 - val_accuracy: 1.0000 - val_loss: 0.0135
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9937 - loss: 0.0345 - val_accuracy: 1.0000 - val_loss: 0.0133
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9939 - loss: 0.0276 - val_accuracy: 1.0000 - val_loss: 0.0118
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9970 - loss: 0.0256 - val_accuracy: 1.0000 - val_loss: 0.0120
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9942 - loss: 0.0269 - val_accuracy: 1.0000 - val_loss: 0.0114
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9876 - loss: 0.0399 - val_accuracy: 1.0000 - val_loss: 0.0108
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9907 - loss: 0.0412 - val_accuracy: 1.0000 - val_loss: 0.0108
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9880 - loss: 0.0378 - val_accuracy: 1.0000 - val_loss: 0.0108
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9936 - loss: 0.0319 - val_accuracy: 1.0000 - val_loss: 0.0101
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9964 - loss: 0.0257 - val_accuracy: 1.0000 - val_loss: 0.0098
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9944 - loss: 0.0305 - val_accuracy: 1.0000 - val_loss: 0.0091
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9912 - loss: 0.0362 - val_accuracy: 1.0000 - val_loss: 0.0092
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9958 - loss: 0.0247 - val_accuracy: 1.0000 - val_loss: 0.0094
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9938 - loss: 0.0271 - val_accuracy: 1.0000 - val_loss: 0.0084
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9965 - loss: 0.0206 - val_accuracy: 1.0000 - val_loss: 0.0082
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9857 - loss: 0.0377 - val_accuracy: 1.0000 - val_loss: 0.0078
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9944 - loss: 0.0217 - val_accuracy: 1.0000 - val_loss: 0.0072
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9962 - loss: 0.0160 - val_accuracy: 1.0000 - val_loss: 0.0070
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9874 - loss: 0.0323 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9970 - loss: 0.0162 - val_accuracy: 1.0000 - val_loss: 0.0065
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9965 - loss: 0.0163 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9914 - loss: 0.0251 - val_accuracy: 1.0000 - val_loss: 0.0056
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9930 - loss: 0.0206 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9911 - loss: 0.0221 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9946 - loss: 0.0163 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9944 - loss: 0.0179 - val_accuracy: 1.0000 - val_loss: 0.0053
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9939 - loss: 0.0167 - val_accuracy: 1.0000 - val_loss: 0.0050
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9960 - loss: 0.0175 - val_accuracy: 1.0000 - val_loss: 0.0049
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9960 - loss: 0.0148 - val_accuracy: 1.0000 - val_loss: 0.0047
# Epoch 72/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9970 - loss: 0.0142 - val_accuracy: 1.0000 - val_loss: 0.0045
# Epoch 73/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9957 - loss: 0.0146 - val_accuracy: 1.0000 - val_loss: 0.0041
# Epoch 74/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9944 - loss: 0.0176 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 75/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9967 - loss: 0.0138 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 76/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9965 - loss: 0.0137 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 77/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9989 - loss: 0.0101 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 78/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9970 - loss: 0.0137 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 79/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9922 - loss: 0.0168 - val_accuracy: 1.0000 - val_loss: 0.0034
# Epoch 80/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9948 - loss: 0.0175 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 81/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9984 - loss: 0.0115 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 82/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9959 - loss: 0.0135 - val_accuracy: 1.0000 - val_loss: 0.0032
# Epoch 83/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9921 - loss: 0.0160 - val_accuracy: 1.0000 - val_loss: 0.0030
# Epoch 84/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9925 - loss: 0.0192 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 85/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9952 - loss: 0.0130 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 86/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9978 - loss: 0.0124 - val_accuracy: 1.0000 - val_loss: 0.0028
# Epoch 87/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9967 - loss: 0.0135 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 88/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9952 - loss: 0.0132 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 89/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9883 - loss: 0.0153 - val_accuracy: 1.0000 - val_loss: 0.0023
# Epoch 90/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9969 - loss: 0.0115 - val_accuracy: 1.0000 - val_loss: 0.0024
# Epoch 91/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9966 - loss: 0.0111 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 92/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9996 - loss: 0.0087 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 93/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9996 - loss: 0.0083 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 94/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9970 - loss: 0.0130 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 95/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9974 - loss: 0.0122 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 96/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9987 - loss: 0.0081 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 97/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9956 - loss: 0.0143 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 98/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9868 - loss: 0.0174 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 99/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9989 - loss: 0.0093 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 100/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9982 - loss: 0.0089 - val_accuracy: 1.0000 - val_loss: 0.0016
#
# --- Training GRU Model (with SMOTE) ---
# Epoch 1/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 3s 35ms/step - accuracy: 0.7823 - loss: 0.5636 - val_accuracy: 0.9739 - val_loss: 0.3382
# Epoch 2/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9517 - loss: 0.3146 - val_accuracy: 0.9652 - val_loss: 0.2301
# Epoch 3/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9653 - loss: 0.2171 - val_accuracy: 0.9739 - val_loss: 0.1799
# Epoch 4/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9723 - loss: 0.1636 - val_accuracy: 0.9739 - val_loss: 0.1490
# Epoch 5/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9805 - loss: 0.1354 - val_accuracy: 0.9826 - val_loss: 0.1266
# Epoch 6/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9706 - loss: 0.1202 - val_accuracy: 0.9826 - val_loss: 0.1101
# Epoch 7/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9825 - loss: 0.1038 - val_accuracy: 0.9826 - val_loss: 0.0970
# Epoch 8/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9765 - loss: 0.0946 - val_accuracy: 0.9913 - val_loss: 0.0847
# Epoch 9/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9781 - loss: 0.0934 - val_accuracy: 0.9913 - val_loss: 0.0760
# Epoch 10/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9888 - loss: 0.0848 - val_accuracy: 0.9913 - val_loss: 0.0663
# Epoch 11/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9865 - loss: 0.0858 - val_accuracy: 0.9913 - val_loss: 0.0599
# Epoch 12/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9915 - loss: 0.0656 - val_accuracy: 0.9913 - val_loss: 0.0562
# Epoch 13/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9781 - loss: 0.0843 - val_accuracy: 0.9913 - val_loss: 0.0504
# Epoch 14/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9828 - loss: 0.0710 - val_accuracy: 0.9913 - val_loss: 0.0455
# Epoch 15/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9898 - loss: 0.0649 - val_accuracy: 0.9913 - val_loss: 0.0420
# Epoch 16/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9855 - loss: 0.0708 - val_accuracy: 0.9913 - val_loss: 0.0400
# Epoch 17/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9865 - loss: 0.0641 - val_accuracy: 0.9913 - val_loss: 0.0385
# Epoch 18/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9846 - loss: 0.0695 - val_accuracy: 0.9913 - val_loss: 0.0366
# Epoch 19/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9820 - loss: 0.0638 - val_accuracy: 0.9913 - val_loss: 0.0342
# Epoch 20/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9841 - loss: 0.0592 - val_accuracy: 0.9913 - val_loss: 0.0327
# Epoch 21/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9798 - loss: 0.0620 - val_accuracy: 0.9913 - val_loss: 0.0320
# Epoch 22/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9906 - loss: 0.0454 - val_accuracy: 0.9913 - val_loss: 0.0305
# Epoch 23/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9850 - loss: 0.0639 - val_accuracy: 0.9913 - val_loss: 0.0289
# Epoch 24/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9917 - loss: 0.0386 - val_accuracy: 0.9913 - val_loss: 0.0291
# Epoch 25/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9835 - loss: 0.0613 - val_accuracy: 0.9913 - val_loss: 0.0274
# Epoch 26/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9917 - loss: 0.0541 - val_accuracy: 0.9913 - val_loss: 0.0267
# Epoch 27/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9771 - loss: 0.0675 - val_accuracy: 0.9913 - val_loss: 0.0240
# Epoch 28/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9833 - loss: 0.0488 - val_accuracy: 0.9913 - val_loss: 0.0239
# Epoch 29/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9848 - loss: 0.0612 - val_accuracy: 0.9913 - val_loss: 0.0240
# Epoch 30/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9913 - loss: 0.0413 - val_accuracy: 0.9913 - val_loss: 0.0232
# Epoch 31/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9879 - loss: 0.0468 - val_accuracy: 0.9913 - val_loss: 0.0228
# Epoch 32/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9896 - loss: 0.0402 - val_accuracy: 0.9913 - val_loss: 0.0218
# Epoch 33/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9911 - loss: 0.0337 - val_accuracy: 0.9913 - val_loss: 0.0220
# Epoch 34/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9825 - loss: 0.0498 - val_accuracy: 0.9913 - val_loss: 0.0206
# Epoch 35/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9855 - loss: 0.0475 - val_accuracy: 0.9913 - val_loss: 0.0192
# Epoch 36/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9913 - loss: 0.0387 - val_accuracy: 0.9913 - val_loss: 0.0205
# Epoch 37/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9850 - loss: 0.0460 - val_accuracy: 0.9913 - val_loss: 0.0199
# Epoch 38/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9939 - loss: 0.0351 - val_accuracy: 0.9913 - val_loss: 0.0181
# Epoch 39/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9979 - loss: 0.0290 - val_accuracy: 0.9913 - val_loss: 0.0181
# Epoch 40/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9877 - loss: 0.0400 - val_accuracy: 0.9913 - val_loss: 0.0171
# Epoch 41/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9952 - loss: 0.0336 - val_accuracy: 0.9913 - val_loss: 0.0169
# Epoch 42/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9876 - loss: 0.0469 - val_accuracy: 0.9913 - val_loss: 0.0161
# Epoch 43/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9954 - loss: 0.0336 - val_accuracy: 0.9913 - val_loss: 0.0157
# Epoch 44/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9929 - loss: 0.0345 - val_accuracy: 1.0000 - val_loss: 0.0149
# Epoch 45/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9927 - loss: 0.0361 - val_accuracy: 0.9913 - val_loss: 0.0163
# Epoch 46/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9942 - loss: 0.0379 - val_accuracy: 0.9913 - val_loss: 0.0157
# Epoch 47/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9940 - loss: 0.0325 - val_accuracy: 0.9913 - val_loss: 0.0151
# Epoch 48/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9959 - loss: 0.0235 - val_accuracy: 1.0000 - val_loss: 0.0137
# Epoch 49/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9880 - loss: 0.0392 - val_accuracy: 1.0000 - val_loss: 0.0128
# Epoch 50/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9884 - loss: 0.0306 - val_accuracy: 1.0000 - val_loss: 0.0129
# Epoch 51/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9961 - loss: 0.0330 - val_accuracy: 1.0000 - val_loss: 0.0136
# Epoch 52/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9966 - loss: 0.0226 - val_accuracy: 1.0000 - val_loss: 0.0120
# Epoch 53/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9956 - loss: 0.0241 - val_accuracy: 1.0000 - val_loss: 0.0118
# Epoch 54/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9906 - loss: 0.0352 - val_accuracy: 1.0000 - val_loss: 0.0106
# Epoch 55/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9926 - loss: 0.0273 - val_accuracy: 1.0000 - val_loss: 0.0112
# Epoch 56/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9962 - loss: 0.0268 - val_accuracy: 1.0000 - val_loss: 0.0112
# Epoch 57/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9917 - loss: 0.0311 - val_accuracy: 1.0000 - val_loss: 0.0112
# Epoch 58/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9897 - loss: 0.0313 - val_accuracy: 1.0000 - val_loss: 0.0110
# Epoch 59/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9903 - loss: 0.0316 - val_accuracy: 1.0000 - val_loss: 0.0096
# Epoch 60/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9952 - loss: 0.0248 - val_accuracy: 1.0000 - val_loss: 0.0090
# Epoch 61/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9931 - loss: 0.0247 - val_accuracy: 1.0000 - val_loss: 0.0090
# Epoch 62/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9972 - loss: 0.0203 - val_accuracy: 1.0000 - val_loss: 0.0088
# Epoch 63/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9979 - loss: 0.0194 - val_accuracy: 1.0000 - val_loss: 0.0086
# Epoch 64/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9981 - loss: 0.0137 - val_accuracy: 1.0000 - val_loss: 0.0076
# Epoch 65/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9920 - loss: 0.0257 - val_accuracy: 1.0000 - val_loss: 0.0074
# Epoch 66/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9895 - loss: 0.0307 - val_accuracy: 1.0000 - val_loss: 0.0054
# Epoch 67/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9989 - loss: 0.0235 - val_accuracy: 1.0000 - val_loss: 0.0057
# Epoch 68/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9969 - loss: 0.0153 - val_accuracy: 1.0000 - val_loss: 0.0060
# Epoch 69/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9936 - loss: 0.0162 - val_accuracy: 1.0000 - val_loss: 0.0058
# Epoch 70/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9938 - loss: 0.0204 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 71/100
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9974 - loss: 0.0158 - val_accuracy: 1.0000 - val_loss: 0.0060
#
# --- Evaluating LSTM Model ---
# LSTM Test Accuracy: 0.9737
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# LSTM Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.97      0.99      0.98        71
#            1       0.98      0.95      0.96        43
#
#     accuracy                           0.97       114
#    macro avg       0.97      0.97      0.97       114
# weighted avg       0.97      0.97      0.97       114
# --- Evaluating GRU Model ---
# GRU Test Accuracy: 0.9825
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 1s 110ms/step
# GRU Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99        71
#            1       0.98      0.98      0.98        43
#
#     accuracy                           0.98       114
#    macro avg       0.98      0.98      0.98       114
# weighted avg       0.98      0.98      0.98       114
